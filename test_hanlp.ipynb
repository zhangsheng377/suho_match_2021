# %%
# import hanlp

# %%
# hanlp.pretrained.tok.ALL

# %%
# t = hanlp.load(hanlp.pretrained.)

# %%
from pyhanlp import *

# %%
print(HanLP.segment('你好，欢迎在Python中调用HanLP的API'))
for term in HanLP.segment('下雨天地面积水'):
    print('{}\t{}'.format(term.word, term.nature)) # 获取单词与词性
testCases = [
    "商品和服务",
    "结婚的和尚未结婚的确实在干扰分词啊",
    "买水果然后来世博园最后去世博会",
    "中国的首都是北京",
    "欢迎新老师生前来就餐",
    "工信处女干事每月经过下属科室都要亲口交代24口交换机等技术性器件的安装工作",
    "随着页游兴起到现在的页游繁盛，依赖于存档进行逻辑判断的设计减少了，但这块也不能完全忽略掉。"]
for sentence in testCases: print(HanLP.segment(sentence))
# 关键词提取
document = "水利部水资源司司长陈明忠9月29日在国务院新闻办举行的新闻发布会上透露，" \
           "根据刚刚完成了水资源管理制度的考核，有部分省接近了红线的指标，" \
           "有部分省超过红线的指标。对一些超过红线的地方，陈明忠表示，对一些取用水项目进行区域的限批，" \
           "严格地进行水资源论证和取水许可的批准。"
print(HanLP.extractKeyword(document, 2))
# 自动摘要
print(HanLP.extractSummary(document, 3))
# 依存句法分析
print(HanLP.parseDependency("徐先生还具体帮助他确定了把画雄鹰、松鼠和麻雀作为主攻目标。"))
# Out:
# [你好/vl, ，/w, 欢迎/v, 在/p, Python/nx, 中/f, 调用/v, HanLP/nx, 的/ude1, API/nx]
# 下雨天	n
# 地面	n
# 积水	n
# [商品/n, 和/cc, 服务/vn]
# [结婚/vi, 的/ude1, 和/cc, 尚未/d, 结婚/vi, 的/ude1, 确实/ad, 在/p, 干扰/vn, 分词/n, 啊/y]
# [买/v, 水果/n, 然后/c, 来/vf, 世博园/n, 最后/f, 去/vf, 世博会/n]
# [中国/ns, 的/ude1, 首都/n, 是/vshi, 北京/ns]
# [欢迎/v, 新/a, 老/a, 师生/n, 前来/vi, 就餐/vi]
# [工信处/n, 女/b, 干事/nnt, 每月/t, 经过/p, 下属/v, 科室/n, 都/d, 要/v, 亲口/d, 交代/v, 24/m, 口/n, 交换机/n, 等/udeng, 技术性/n, 器件/n, 的/ude1, 安装/v, 工作/vn]
# [随着/p, 页游/nz, 兴起/v, 到/v, 现在/t, 的/ude1, 页游/nz, 繁盛/a, ，/w, 依赖于/v, 存档/vi, 进行/vn, 逻辑/n, 判断/v, 的/ude1, 设计/vn, 减少/v, 了/ule, ，/w, 但/c, 这/rzv, 块/q, 也/d, 不能/v, 完全/ad, 忽略/v, 掉/v, 。/w]
# [水资源, 陈明忠]
# [严格地进行水资源论证和取水许可的批准, 有部分省超过红线的指标, 水利部水资源司司长陈明忠9月29日在国务院新闻办举行的新闻发布会上透露]
# 1	徐先生	徐先生	nh	nr	_	4	主谓关系	_	_
# 2	还	还	d	d	_	4	状中结构	_	_
# 3	具体	具体	a	ad	_	4	状中结构	_	_
# 4	帮助	帮助	v	v	_	0	核心关系	_	_
# 5	他	他	r	r	_	4	兼语	_	_
# 6	确定	确定	v	v	_	4	动宾关系	_	_
# 7	了	了	u	u	_	6	右附加关系	_	_
# 8	把	把	p	p	_	15	状中结构	_	_
# 9	画	画	v	v	_	8	介宾关系	_	_
# 10	雄鹰	雄鹰	n	n	_	9	动宾关系	_	_
# ...

# %%
data = {"source": "如何刻画时代人物?王凯、董子健谈《大江大河2》演绎感悟", "target": "目前，电视剧《大江大河2》正在东方卫视东方剧场热播，该剧由上海广播电视台、正午阳光、SMG尚世影业出品，王凯、杨烁、董子健、杨采钰领衔主演。播出一周，《大江大河2》口碑与收视不俗，豆瓣评分高达9.3分，为2020年国产剧最高评分。收视成绩上也十分亮眼，截止12月29日，东方卫视CSM59城平均收视1.831%，单集最高收视2.388%，已连续五天收视破2%。 董子健在剧中饰演个体户杨巡，他在商海里摸爬滚打的经历，反映了一代人的奋斗历程。近日，他接受了东方卫视组织的全国媒体微信群访，解读角色、分享拍摄感悟。  谈人物：他的优点缺点都很多 剧中，杨巡是个体经济的代表者。第一部中，他靠卖馒头、山货赚取第一桶金，之后经营扬子街电器市场，事业发展如火如荼。第二部中，他瞄准了东海的发展潜力，筹建批发市场。随着故事推进，杨巡的“小人物”特征愈发明显：他既谦卑又自信，既谨慎又大胆，既明理又滑头。董子健说：“拍完第二部也没改变我对杨巡的理解，一直以来，他的优点和缺点都很多。” 最近播出的剧情中，杨巡为了在东海搞事业，到处托关系、求人，十分活络。董子健欣赏角色身上那股爱拼的劲头：“他该应酬就应酬，该赔笑脸就赔笑脸。他聪明勤奋、内心足够强大，能做成很多意想不到的事。”与此同时，搞事业的艰难也体现在杨巡身上，他要面对无数突发状况：市场出乱子、雷东宝被调查、租用地块受阻……董子健也看到了杨巡的渺小：“我会对他产生一些同情。” 对于捕捉人物，董子健从造型到表演做到了真实。有生活中的参照对象吗？他表示参照对象就是杨巡本身：“在演《大江大河》第一部时，我还会思考他是谁，但演第二部时，我感觉回到了这个人物身上，所以，我演得很自然。”  谈时代：唤起了我的童年记忆 《大江大河2》讲述的是上世纪80年代末至90年代初的故事，对应杨巡的故事线，他正在经历个体经济的蓬勃发展时期。董子健感受到了时代对个体的塑造：“杨巡是一个缩影，从年轻时就‘走出来’干活、创业，慢慢努力，希望自己能进步、有成长，这就是我们。” 生于1993年的董子健表示，由于和角色的成长年代不同，所以共鸣不是很多。不过，他仍能感受到全剧置景对时代感的真实还原：“我爷爷奶奶以前开小卖部，剧中的小卖部让我特别亲切，里面卖的东西也一样，有童年记忆的感觉。” 演完这部剧，董子健也感受到了时代对自己的影响：“得益于改革开放，我的生活更加幸福，小时候长那么胖，直到现在，我还在努力让自己减减肥。”  感慨：与原班底合作很开心 去年《大江大河2》在宁波开机。今年1月底，受新冠肺炎疫情影响，为避免剧组工作人群聚集，剧组暂停拍摄，原地休整，于3月13日恢复拍摄，直到4月24日，该剧大组戏份全部杀青。谈及这段经历，董子健说：“疫情期间，全剧组的人都待在同一个酒店里，但互相见不到，复拍时感觉很振奋。” 《大江大河2》基本保留了第一部的制作及演员班底。搞事业的“三巨头”重新聚首——董子健饰演的杨巡依然与王凯饰演的宋运辉、杨烁饰演的雷东宝有大量对手戏。董子健感慨道：“拍完第一部之后还有再聚到一起的机会很不容易，再次和他们合作，我很荣幸、很开心。” 采访中，董子健还谈到了自己的新年愿望：“我不太爱跨年，但心里还是会默默许下新年愿望。今年比较特殊，希望大家新的一年里可以健康平安、越来越好，也请大家多多支持《大江大河2》。” 更多精彩内容，关注东方卫视每晚19:30正在热播的《大江大河2》。", "labelB": "1"}
# a = HanLP.extractSummary(data['source'], 20)
# a_ = str(a)
# print(a, type(a), a_, type(a_), a_[1:-1])
print(HanLP.extractSummary(data['target'], 50))
# Out:
# [董子健在剧中饰演个体户杨巡, 在演《大江大河》第一部时, 杨巡为了在东海搞事业, 电视剧《大江大河2》正在东方卫视东方剧场热播, 《大江大河2》口碑与收视不俗, 与原班底合作很开心 去年《大江大河2》在宁波开机, 董子健感慨道, 董子健也感受到了时代对自己的影响, 搞事业的艰难也体现在杨巡身上, 董子健欣赏角色身上那股爱拼的劲头, 30正在热播的《大江大河2》, 他表示参照对象就是杨巡本身, 董子健说, 董子健说, 唤起了我的童年记忆 《大江大河2》讲述的是上世纪80年代末至90年代初的故事, 董子健还谈到了自己的新年愿望, 东方卫视CSM59城平均收视1.831%, 市场出乱子、雷东宝被调查、租用地块受阻……董子健也看到了杨巡的渺小, 剧组暂停拍摄, 杨巡的, 董子健感受到了时代对个体的塑造, 生于1993年的董子健表示, 单集最高收视2.388%, 我感觉回到了这个人物身上, 为2020年国产剧最高评分, 重新聚首——董子健饰演的杨巡依然与王凯饰演的宋运辉、杨烁饰演的雷东宝有大量对手戏, 对应杨巡的故事线, 最近播出的剧情中, 杨巡是个体经济的代表者, 也请大家多多支持《大江大河2》, 拍完第二部也没改变我对杨巡的理解, 他的优点缺点都很多 剧中, 杨巡是一个缩影, 他正在经历个体经济的蓬勃发展时期, 第二部中, 董子健从造型到表演做到了真实, 《大江大河2》基本保留了第一部的制作及演员班底, 收视成绩上也十分亮眼, 采访中, 里面卖的东西也一样, 我还在努力让自己减减肥, 已连续五天收视破2%, 由于和角色的成长年代不同, 全剧组的人都待在同一个酒店里, 王凯、杨烁、董子健、杨采钰领衔主演, 解读角色、分享拍摄感悟, 搞事业的, 事业发展如火如荼, 关注东方卫视每晚19, 剧中的小卖部让我特别亲切]
